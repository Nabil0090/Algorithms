# %%
#task1b
def sum_pair(arr,target):
  size=len(arr)
  left=0
  right=size-1
  old_arr=[]
  for i in arr:
    old_arr.append(i)
  arr.sort()
  flag=0
  for i in range(size):
    if arr[left]+arr[right]==target:
        flag=1
        print(f"{left} {right}", file=output_file)
        break
    elif arr[left]+arr[right]>target:
        right-=1
        flag=0
    elif arr[left]+arr[right]<target:
        left+=1
        flag=0
  if flag==0:
    print("Impossible", file=output_file)



input_file=open('/content/input1b.txt','r')
output_file=open('output1b.txt','w')

size, target = map(int, input_file.readline().split())
arr = list(map(int, input_file.readline().split()))
sum_pair(arr,target)
output_file.close()
